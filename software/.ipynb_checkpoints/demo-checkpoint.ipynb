# %% [markdown]
# Imports

# %%
import time
import os
import ipywidgets as widgets
from enum import Enum
from pynq import Overlay, allocate
from IPython.display import display, clear_output

from axi.driver import SimpleAxiMasterDriver
from axi.enums import MemSize, MemOpStatus

# %% [markdown]
# Set up hardware and allocate buffer.

# %%
print('Initializing hardware...')
BITSTREAM_PATH = '../overlay/demo.bit'

if not os.path.exists(BITSTREAM_PATH):
    raise FileNotFoundError(f'Bitstream not found at {BITSTREAM_PATH}. Run \'make bitstream\'.')

driver = SimpleAxiMasterDriver(BITSTREAM_PATH)

print('Hardware initialized!')
print('Allocating buffer...')

# Allocate 1024 * 4B buffer
buffer = allocate(shape=(1024,), dtype='u4')
buffer_addr = buffer.physical_address

print(f'DDR buffer allocated at {hex(buffer_addr)}')
# Out:
# Initializing hardware...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 6>()
#       4 if not os.path.exists(BITSTREAM_PATH):
#       5     raise FileNotFoundError(f'Bitstream not found at {BITSTREAM_PATH}. Run \'make bitstream\'.')
# ----> 6 driver = SimpleAxiMasterDriver(BITSTREAM_PATH)
#       8 print('Hardware initialized!')
#       9 print('Allocating buffer...')
#
# File /home/xilinx/repos/simple-axi-master/software/axi/driver.py:11, in SimpleAxiMasterDriver.__init__(self, overlay_path)
#       8 def __init__(self, overlay_path: Path) -> None:
#       9     self._ol = Overlay(overlay_path)
# ---> 11     self.gpio_wdata = self._ol.gpio_wdata.channel1
#      12     self.gpio_rdata = self._ol.gpio_rdata.channel1
#      13     self.gpio_addr = self._ol.gpio_addr.channel1
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/pynq/overlay.py:369, in Overlay.__getattr__(self, key)
#     364 """Overload of __getattr__ to return a driver for an IP or
#     365 hierarchy. Throws an `RuntimeError` if the overlay is not loaded.
#     366
#     367 """
#     368 if self.is_loaded():
# --> 369     return getattr(self._ip_map, key)
#     370 else:
#     371     raise RuntimeError("Overlay not currently loaded")
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/pynq/overlay.py:832, in _IPMap.__getattr__(self, key)
#     830     return mem
#     831 else:
# --> 832     raise AttributeError(
#     833         "Could not find IP or hierarchy {} in overlay".format(key)
#     834     )
#
# AttributeError: Could not find IP or hierarchy gpio_wdata in overlay

# %% [markdown]
# Set up UI.

# %%
w_addr = widgets.Text(value=hex(buffer_addr), description="Addr:")
w_data = widgets.Text(value="0xDEADBEEF", description="Data:")
btn_run = widgets.Button(description="Write Data", button_style='warning')
out_log = widgets.Output()

def on_click(b):
    with out_log:
        addr = int(w_addr.value, 16)
        data = int(w_data.value, 16)
        
        result = driver._execute(cmd=1, size=2, addr=addr, data=data)
        
        if result.status != MemOpStatus.DONE:
            print("Error!")
        else:
            print("Success!")

btn_run.on_click(on_click)
display(widgets.VBox([w_addr, w_data, btn_run, out_log]))
